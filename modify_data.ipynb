# %%
import os
import json

input_folder = "data/DST"
output_file = "data/article_identifiers.txt"

identifiers = []

for filename in os.listdir(input_folder):
    if filename.endswith(".json"):
        file_path = os.path.join(input_folder, filename)
        try:
            with open(file_path, "r", encoding="utf-8") as f:
                data = json.load(f)

            value = data.get("dc:identifier")
            if value is not None:
                identifiers.append(str(value))

        except (json.JSONDecodeError, UnicodeDecodeError) as e:
            print(f"Skipping {filename}: {e}")

with open(output_file, "w+", encoding="utf-8") as f:
    for item in identifiers:
        f.write(item + "\n")

print(f"Wrote {len(identifiers)} identifiers to {output_file}")
# Out:
# Wrote 33571 identifiers to data/article_identifiers.txt
